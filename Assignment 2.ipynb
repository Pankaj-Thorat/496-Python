# %% [markdown]
# ## Test on built-in data types and basic operators
#
# #### Instructions
#
# * Please make a copy of this notebook, DO NOT MODIFY THIS NOTEBOOK
#
# * You are expected to write code as answer, not the final result, eg.
# ```
#     Q: What is length of this list l = [0, 2, 3]
#     Wrong Answer: 3
#     Right Answer: len(l)
# ```
# * You are free to refer to class videos, class material or any other online resource (It is advised to restrict yourself to official documentation - https://docs.python.org/3/). Also be careful that you are refering to Python 3 resources and not Python 2. Python 2 is no longer supported.
# * Please attempt the answers yourself, do not try to copy answers

# %% [markdown]
# # Exercise 1
#
# Please write a small code to calculate hypotenuse of a right triangle. The program should work in following steps-
# 1. Ask user - Please enter lenght of side A:
# 2. Ask user - Please enter lenght of side B:
# 3. Calculate hypotenuse
# 4. Print - Length of hypotenuse is ___

# %% [markdown]
# # Exercise 1
#
# Please write a small code to calculate hypotenuse of a right triangle. The program should work in following steps-
# 1. Ask user - Please enter lenght of side A:
# 2. Ask user - Please enter lenght of side B:
# 3. Calculate hypotenuse
# 4. Print - Length of hypotenuse is ___

# %%
# Ans here

# %% [markdown]
# # Exercise 2
#
# Variable `paragraph` contains an extract from a news article. There are some questions related to this in below cells. Please write your answers in cells below each question.
#
# **Please execute below cell before writing answers**

# %%
paragraph = "India celebrates its Republic Day on January 20 every year.\
This year, the country will celebrate its 73rd Republic Day to mark the day India became a sovereign republic. \
It commemorates the date when the Constitution of India finally came into effect on January 20, 1950. \
This resulted in India becoming the largest democracy that it is today."

# %% [markdown]
# Q1. How many times word "India" appeaers in the paragraph. (do not count manually, write code please)

# %% [markdown]
# Q2. The reporter has made a mistake with date of republic day, can you please replace date 20 with correct date

# %% [markdown]
# Q3. How many letters and numbers are present in paragraph (Exclude whitespaces, full stops and commas)

# %% [markdown]
# # Exercise 3
#
# `all_employees` is a list of all employees. The are arranged in terms of their employee ID, `Ramiro Jimenez` getting employee id of 0 and so on.
#
# Execute below cell first and proceed to answering below questions

# %%
all_employees = ['Ramiro Jimenez', 'Alicia Weiss', 'Kurt Morrison', 'Andy Hobbs', 'Wilford Suarez', 
                 'Lucien Gaines', 'Maura Chung', 'Jamaal Barrett', 'Diane Glass', 'Lavern Lindsey', 
                 'Tanya Petersen', 'Leanna Stout', 'Aurelio Huang', 'Sid Davies', 'Herman Dyer', 
                 'Quincy Collier', 'Jackie Gray', 'Olen Walton', 'Susie Zuniga', 'Hope Berger']

# %% [markdown]
# Q1. What is employee id of 'Jackie Gray'? (Do not write number directly, please write code)

# %% [markdown]
# Q2. "Andy Hobbs" has requested a spelling correction in his name to "Andrew Hobbs", Update the list with name correction without affecting other employees

# %% [markdown]
# Q3. New employee has joined the company 'Davin Brock', please add it to the list and return his employee id

# %% [markdown]
# Q4. 'Herman Dyer' has left the company, please remove him from the list

# %% [markdown]
# Q5. How many employees does company have?

# %% [markdown]
# Last five employees are senior management employee
#
# Q6. Please extract list of senior management
#
# Q7. Please extract normal staff (Which are not in management positions)

# %%
# Q6

# %%
# Q7

# %% [markdown]
# # Exercise 4
#
# `all_students` is a list of all students. `vaccinated_students` is a list of all vaccinated students.
#
# Execute below cell first and proceed to answering below questions

# %%
all_students = ['Adaline Santiago', 'Adnan Mcghee', 'Jameson Greene', 'Davina Brock', 'Shelly Maldonado', 
                'Johnnie Acosta', 'Reya Everett', 'Michael Pena', 'Kamran Savage', 'Scarlet Mullins', 
                'Kendra Gilbert', 'Ephraim Romero', 'Guto Charlton', 'Sahib Nicholls', 'Aarush Tomlinson', 
                'Arman Finnegan', 'Manha Sellers', 'Shamas Bryan', "Peter O'Sullivan", 'Layan Berger', 
                'Kathryn Dickerson', 'Ananya Ortega', 'Shoaib Bate', 'Margaret Franco', 'Tyron Stark', 
                'Shanna Calvert', 'Deon Foley', 'Loretta Soto', 'Saara Christie', 'Markus Beasley', 'Cindy Fowler',
                'Ada Hastings', 'Makayla Marriott', 'Kie Piper', 'Rahima Welsh', 'Neriah Barnett', 
                'Tehya Hartley', 'Lillian Howell', 'Abu Koch', 'Elis Prentice']

vaccinated_students = ['Guto Charlton', 'Sahib Nicholls', 'Aarush Tomlinson', 
                'Arman Finnegan', 'Manha Sellers', 'Shamas Bryan', "Peter O'Sullivan", 'Layan Berger', 
                'Kathryn Dickerson', 'Ananya Ortega', 'Shoaib Bate', 'Margaret Franco', 'Tyron Stark', 
                'Shanna Calvert', 'Deon Foley', 'Loretta Soto', 'Saara Christie', 'Markus Beasley', 'Cindy Fowler',
                'Ada Hastings', 'Makayla Marriott', 'Kie Piper', 'Rahima Welsh']

# %% [markdown]
# Q1. How many students are there

# %% [markdown]
# Q2. What percentage of students have been vaccinated?

# %% [markdown]
# Q3. Can you find a list of students who are still not vaccinated

# %% [markdown]
# ## Exercise 5
#
# A school has stored marks of students in a Python dictionary, the school has two subjects "maths" and "physics". The pattern of dictionary is as follows-
#
# ```python
# {
#     roll_no_1: {
#                       'name': "student1 name",
#                       'subject1': score1,
#                       'subject2': score2,
#     }
#     roll_no_2:{
#                         'name': "student2 name",
#                         'subject1': score1,
#                         and so on
#     }
#     ...
# }
# ```
#
# **First execute below statement and then proceed to answer questions below**

# %%
marks = {
    1: {
        "name": 'Ramiro Jimenez',
        "maths": 80,
        "physics": 90, 
    },
    2: {
        "name": 'Aarush Tomlinson',
        "maths": 70,
        "physics": 60, 
    },
}

# %% [markdown]
# Q1. What is name of the student with roll no 1

# %% [markdown]
# Q2. What is the physics score of roll no 2

# %% [markdown]
# Q3. There is a correction in physics score for roll no 1, from 90 to 85

# %% [markdown]
# Q4. There is addition of student with roll no 3 and below details
#
# name: 'Kie Piper'
#
# math: 50
#
# physics: 60

# %% [markdown]
# Q5. Roll no 1 has left the school, delete all the information related to him, without affecting others
